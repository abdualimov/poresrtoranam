# %%
import pandas as pd
import pandas_profiling
from datetime import datetime, timedelta
from ast import literal_eval
import numpy as np
import seaborn as sns
import requests
import re
rest2 = pd.read_csv('kaggle_task.csv')
rest1 = pd.read_csv('main_task.csv')
rest1['sample'] = 1
rest2['sample'] = 0
rest2['Rating'] = 0
rest = rest2.append(rest1, sort = False).reset_index(drop = True)

# %%
rest['link'] = rest['URL_TA'].apply(lambda x: 'http://tripadvisor.com' + x)

# %%
def poisk(s):
    print(rest.loc[rest['link'] == s].index)
    try:
        return re.findall(r"row_num \">(\d+?)<", requests.get(s).text)
        a += 1
    except:
        return 0
        a += 1

# %%
# %%time
rest['WOW'] = rest['link'][0:5].apply(poisk)
# Out:
# Int64Index([0], dtype='int64')
# Int64Index([1], dtype='int64')
# Int64Index([2], dtype='int64')
# Int64Index([3], dtype='int64')
# Int64Index([4], dtype='int64')
# CPU times: user 417 ms, sys: 63.6 ms, total: 481 ms
# Wall time: 10.2 s

# %%
rest.to_csv('rest.csv', index=False)

# %%
rest.loc[rest['link'] == 'http://tripadvisor.com/Restaurant_Review-g187147-d10746918-Reviews-Le_Perchoir-Paris_Ile_de_France.html'].index[0]
# Out:
# 0

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-340bb95f84f6> in <module>
# ----> 1 rest.query['link' == 'http://tripadvisor.com/Restaurant_Review-g187147-d10746918-Reviews-Le_Perchoir-Paris_Ile_de_France.html']
#
# TypeError: 'method' object is not subscriptable

# %%
time.sleep(5)

# %%
import pandas as pd

# %%
# %%time
response = requests.get('http://en.wikipedia.org')
# Out:
# CPU times: user 56.2 ms, sys: 7.18 ms, total: 63.3 ms
# Wall time: 349 ms

# %%
# %%time
response = requests.get('https://www.tripadvisor.ru/')
# Out:
# CPU times: user 46.7 ms, sys: 7.1 ms, total: 53.8 ms
# Wall time: 963 ms

# %%
# %%time
re.findall(r"row_num \">(\d+?)<", requests.get('https://www.tripadvisor.com/Restaurant_Review-g187147-d4990732-Reviews-Le_Perchoir-Paris_Ile_de_France.html#REVIEWS', stream=True).text)
# Out:
# CPU times: user 63.2 ms, sys: 12.3 ms, total: 75.5 ms
# Wall time: 2.07 s
# ['52', '39', '11', '4', '10']

# %%
try:
    a = re.findall(r"row_num \">(\d+?)<", requests.get('https://www.tripadvisor.com/Restaurant_Review-g187147-d4990732-Reviews-Le_Perchoir-Paris_Ile_de_France.html#REVIEWS', timeout=0.5))
except:
    0

# %%
requests.get('https://www.tripadvisor.com/Restaurant_Review-g187147-d4990732-Reviews-Le_Perchoir-Paris_Ile_de_France.html#REVIEWS', headers={"content-type":"text"})
# Out:
# <Response [400]>

# %%
open('https://github.com/Lispython/pycurl/blob/master/examples/retriever-multi.py')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-68-a5213442e4cb> in <module>
# ----> 1 open('https://github.com/Lispython/pycurl/blob/master/examples/retriever-multi.py')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Lispython/pycurl/blob/master/examples/retriever-multi.py'

# %%
# %%time
re.findall(r"row_num \">(\d+?)<", requests.get("https://www.tripadvisor.com/Restaurant_Review-g187147-d4990732-Reviews-Le_Perchoir-Paris_Ile_de_France.html#REVIEWS", headers={"class":"choices"}).text)
# Out:
# CPU times: user 65.4 ms, sys: 12.2 ms, total: 77.6 ms
# Wall time: 1.15 s
# ['52', '39', '11', '4', '10']

# %%
requests.get("https://www.tripadvisor.com/Restaurant_Review-g187147-d4990732-Reviews-Le_Perchoir-Paris_Ile_de_France.html#REVIEWS").text
# Out:
# '<!DOCTYPE html><html lang="en" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta http-equiv="content-type" content="text/html; charset=utf-8"/><link rel="icon" id="favicon" href="https://static.tacdn.com/favicon.ico" type="image/x-icon" /><link rel="mask-icon" sizes="any" href="https://static.tacdn.com/img2/icons/ta_square.svg" color="#00a680" /><meta name="theme-color" content="#00a680" /><meta name="format-detection" content="telephone=no" /><script type="text/javascript">window.taRollupsAreAsync = true;</script><title>Le Perchoir, Paris - 11th Arr. - Popincourt - Restaurant Reviews, Photos &amp; Phone Number - TripAdvisor</title><meta property="al:ios:app_name" content="TripAdvisor"><meta property="al:ios:app_store_id" content="284876795"><meta property="twitter:app:id:ipad" name="twitter:app:id:ipad" content="284876795"><meta property="twitter:app:id:iphone" name="twitter:app:id:iphone" content="284876795"><meta property="al:ios:url" content="tripadvisor://www.tripadvi
# ...

# %%
p
# Out:
# [<p#hello.hello>]

# %%
requests.head("https://www.tripadvisor.com/Restaurant_Review-g187147-d4990732-Reviews-Le_Perchoir-Paris_Ile_de_France.html#REVIEWS").text
# Out:
# ''

# %%
getoutput('curl -m6 -Ss "https://www.tripadvisor.com/Restaurant_Review-g187147-d4990732-Reviews-Le_Perchoir-Paris_Ile_de_France.html#REVIEWS"')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5898bef27fc3> in <module>
# ----> 1 getoutput('curl -m6 -Ss "https://www.tripadvisor.com/Restaurant_Review-g187147-d4990732-Reviews-Le_Perchoir-Paris_Ile_de_France.html#REVIEWS"')
#
# NameError: name 'getoutput' is not defined

# %%
from requests import get

# %%
# %%time
get("https://www.tripadvisor.com/Restaurant_Review-g187147-d4990732-Reviews-Le_Perchoir-Paris_Ile_de_France.html#REVIEWS")
# Out:
# CPU times: user 63.3 ms, sys: 10.9 ms, total: 74.2 ms
# Wall time: 1.92 s
# <Response [200]>

# %%
import faster_than_requests as requests

# %%
apt-get remove python-requests
apt-get install libffi-dev
pip install --upgrade requests
pip install --upgrade pyOpenSSL
# Out:
#   File "<ipython-input-15-fe5ad380a071>", line 1
#     apt-get remove python-requests
#                  ^
# SyntaxError: invalid syntax

# %%
pd.read_html('https://www.tripadvisor.ru/Restaurant_Review-g187147-d4990732-Reviews-Le_Perchoir-Paris_Ile_de_France.html/')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-84b59942317d> in <module>
# ----> 1 pd.read_html('https://www.tripadvisor.ru/Restaurant_Review-g187147-d4990732-Reviews-Le_Perchoir-Paris_Ile_de_France.html/')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
#     913
#     914     ret = []
#
# ...

# %%
import scrapy
